# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("superstore.csv", encoding='latin1')

# Convert date column
df['Order Date'] = pd.to_datetime(df['Order Date'])

# Group sales by date
df = df.groupby('Order Date')['Sales'].sum().reset_index()

# Set index
df.set_index('Order Date', inplace=True)

# Plot sales over time
plt.figure()
plt.plot(df['Sales'])
plt.title("Sales Over Time")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.show()

# %%
# Load dataset
df = pd.read_csv("superstore.csv", encoding='latin1')

# Convert date column
df['Order Date'] = pd.to_datetime(df['Order Date'])

# Group sales by date
df = df.groupby('Order Date')['Sales'].sum().reset_index()

# Set index
df.set_index('Order Date', inplace=True)

# Plot sales over time
plt.figure()
plt.plot(df['Sales'])
plt.title("Sales Over Time")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.show()

# %%
from sklearn.metrics import mean_absolute_error
print("MAE:", mean_absolute_error(y_test, pred))

import pandas as pd
import matplotlib.pyplot as plt

# Create future dates (start from next day)
future_dates = pd.date_range(
    start=df.index[-1] + pd.Timedelta(days=1),
    periods=30
)

# Create future dataframe
future_df = pd.DataFrame({
    'day': future_dates.day,
    'month': future_dates.month,
    'year': future_dates.year
})

# Predict future sales
future_preds = model.predict(future_df)

# Plot
plt.figure(figsize=(14,6))

# Past sales
plt.plot(
    df.index,
    df['Sales'],
    label="Past Sales"
)

# Future predictions
plt.plot(
    future_dates,
    future_preds,
    label="Future Prediction",
    linestyle='dashed',
    linewidth=3
)

# Add vertical line to separate future
plt.axvline(
    x=df.index[-1],
    linestyle=':',
    linewidth=2
)

plt.legend()
plt.title("Sales Forecast (Future Prediction)")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.grid(True)

plt.show()
# Out:
# MAE: 1754.4341734269497

# %%
# -------------------------------
# SHOW COMPLETE SALES HISTORY
# -------------------------------

# Total sales
print("Total Sales:", df['Sales'].sum())

# Highest sales day
print("Highest Sales:", df['Sales'].max())

# Lowest sales day
print("Lowest Sales:", df['Sales'].min())

# Average sales
print("Average Daily Sales:", df['Sales'].mean())

# Plot full historical sales trend
plt.figure(figsize=(12,5))
plt.plot(df.index, df['Sales'], label='Historical Sales')

# Optional: Add moving average line
df['Moving_Avg'] = df['Sales'].rolling(window=30).mean()
plt.plot(df.index, df['Moving_Avg'], label='30-Day Moving Average')

plt.title("Complete Sales History")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Total Sales: 2297200.8603
# Highest Sales: 28106.716
# Lowest Sales: 2.025
# Average Daily Sales: 1857.0742605497169
